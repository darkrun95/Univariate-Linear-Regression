# %% [markdown]
# ### Import Pandas and Numpy

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib notebook

# %% [markdown]
# ### Load housing dataset

# %%
houses_df = pd.read_csv("input.csv")

# %% [markdown]
# ### Select Feature Vectors

# %%
keep_col = [
    "price",
    "sqft_lot"
]

houses_df = houses_df[keep_col]
houses_df.columns= ["price", "sqft"]
houses_df["price"] = houses_df["price"].apply(lambda x: x/1000)
houses_df["sqft"] = houses_df["sqft"].apply(lambda x: x/1000)

# %% [markdown]
# ### Linear Regression Model
#
# h(x) = c + mx
#
# where,<br/>
# h(x) = price of house to be predicted<br/>
# x = square feet of house<br/>
# c, m = constants

# %% [markdown]
# ### Line by line evaluation

# %%
m = 0
c = 0
fig = plt.figure()
_ = plt.scatter(houses_df["sqft"], houses_df["price"], s=15)

learning_rate = 0.0001
total_obs = len(houses_df)

new_m = m
new_c = c

def calculate_error():
    global new_m
    global new_c
    
    error_sum = 0
    for index, sample in houses_df.iterrows():
        error_sum += (((new_c + (new_m * sample["sqft"])) - sample["price"]) ** 2) 
    error = error_sum / (2 * total_obs)
    return error

def calculate_m_deriv():
    global new_m
    global new_c
    
    m_sum = 0
    for index, sample in houses_df.iterrows():
        m_sum += ((new_c + (new_m * sample["sqft"])) - sample["price"])
    return m_sum

def calculate_c_deriv():
    global new_m
    global new_c
    
    c_sum = 0
    for index, sample in houses_df.iterrows():
        c_sum += (((new_c + (new_m * sample["sqft"])) - sample["price"]) * sample["sqft"])
    return c_sum

iterations = 0
while True:   
    temp_m = new_m - (learning_rate * calculate_m_deriv()) / total_obs
    temp_c = new_c - (learning_rate * calculate_c_deriv()) / total_obs

    if temp_m > new_m and temp_c > new_c:
        new_m = temp_m
        new_c = temp_c
    else:
        new_m = temp_m
        new_c = temp_c
        break
    iterations += 1
print("Training complete")
print("Total Iterations: ", iterations)
print("m: ", new_m)
print("c: ", new_c)
print("Total error: ", calculate_error())

x_min, x_max = plt.gca().get_xlim()
y_min, y_max = new_c, new_c + (new_m * (x_max - x_min))
_ = plt.plot([x_min, x_max], [y_min, y_max], color="r", linewidth=0.5)

_ = plt.gca().set_ylim(-1000, np.max(houses_df["price"]))
_ = plt.gca().set_title("Univariate Linear Regression")
_ = plt.gca().set_xlabel("Square Feet")
_ = plt.gca().set_ylabel("Price in 1000")
# Out:
# <img src="data:image/png;base64,..." width="640">
# Training complete
# Total Iterations:  96
# m:  4.60799467574
# c:  43.3756944491
# Total error:  170526.672963

# %% [markdown]
# ### Batch Processing

# %%
m = 0
c = 0
fig = plt.figure()
_ = plt.scatter(houses_df["sqft"], houses_df["price"], s=15)

learning_rate = 0.0001
total_obs = len(houses_df)

new_m = m
new_c = c

def calculate_error():
    global new_m
    global new_c
    
    error_sum = 0
    df = houses_df.copy()
    df["slope"] = df["sqft"] * new_m
    df["slope"] = df["slope"] + new_c
    df["slope"] = df["slope"] - df["price"]
    df["slope"] = df["slope"] ** 2
    error_sum = df["slope"].sum()
    del df
    error = error_sum / (2 * total_obs)
    return error

def calculate_m_deriv():
    global new_m
    global new_c
    
    m_sum = 0

    df = houses_df.copy()
    df["slope"] = df["sqft"] * new_m
    df["slope"] = df["slope"] + new_c
    df["slope"] = df["slope"] - df["price"]
    m_sum = df["slope"].sum()
    del df
    return m_sum

def calculate_c_deriv():
    global new_m
    global new_c
    
    c_sum = 0
    df = houses_df.copy()
    df["slope"] = df["sqft"] * new_m
    df["slope"] = df["slope"] + new_c
    df["slope"] = df["slope"] - df["price"]
    df["slope"] = df["slope"] * df["sqft"]
    c_sum = df["slope"].sum()
    del df
    return c_sum

iterations = 0
while True:   
    temp_m = new_m - (learning_rate * calculate_m_deriv()) / total_obs
    temp_c = new_c - (learning_rate * calculate_c_deriv()) / total_obs

    if temp_m > new_m and temp_c > new_c:
        new_m = temp_m
        new_c = temp_c
    else:
        new_m = temp_m
        new_c = temp_c
        break
    iterations += 1
    
print("Training complete")
print("Total Iterations: ", iterations)
print("m: ", new_m)
print("c: ", new_c)
print("Total error: ", calculate_error())

x_min, x_max = plt.gca().get_xlim()
y_min, y_max = new_c, new_c + (new_m * (x_max - x_min))
_ = plt.plot([x_min, x_max], [y_min, y_max], color="r", linewidth=0.5)

_ = plt.gca().set_ylim(-1000, np.max(houses_df["price"]))
_ = plt.gca().set_title("Univariate Linear Regression")
_ = plt.gca().set_xlabel("Square Feet")
_ = plt.gca().set_ylabel("Price in 1000")
# Out:
# <img src="data:image/png;base64,..." width="640">
# Training complete
# Total Iterations:  96
# m:  4.60799467574
# c:  43.3756944491
# Total error:  170526.672963

# %%
from sklearn.linear_model import LinearRegression

fig = plt.figure()
_ = plt.scatter(houses_df["sqft"], houses_df["price"], s=15)

linearmodel = LinearRegression().fit([houses_df["sqft"], houses_df["price"]])
m = linearmodel.coef_
c = linearmodel.intercept_

x_min, x_max = plt.gca().get_xlim()
y_min, y_max = c, c + (m * (x_max - x_min))
_ = plt.plot([x_min, x_max], [y_min, y_max], color="r", linewidth=0.5)

_ = plt.gca().set_ylim(-1000, np.max(houses_df["price"]))
_ = plt.gca().set_title("Univariate Linear Regression")
_ = plt.gca().set_xlabel("Square Feet")
_ = plt.gca().set_ylabel("Price in 1000")
# Out:
# <div id='7ca6cba9-5fbc-46e5-989d-662eff851fb2'></div>
# /usr/local/lib/python3.5/dist-packages/sklearn/utils/validation.py:395: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   DeprecationWarning)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-22-c35adcb0cbab> in <module>()
#       4 _ = plt.scatter(houses_df["sqft"], houses_df["price"], s=15)
#       5
# ----> 6 linearmodel = LinearRegression().fit(houses_df["sqft"], houses_df["price"])
#       7 m = linearmodel.coef_
#       8 c = linearmodel.intercept_
#
# /usr/local/lib/python3.5/dist-packages/sklearn/linear_model/base.py in fit(self, X, y, sample_weight)
#     510         n_jobs_ = self.n_jobs
#     511         X, y = check_X_y(X, y, accept_sparse=['csr', 'csc', 'coo'],
# --> 512                          y_numeric=True, multi_output=True)
#     513
#     514         if sample_weight is not None and np.atleast_1d(sample_weight).ndim > 1:
#
# /usr/local/lib/python3.5/dist-packages/sklearn/utils/validation.py in check_X_y(X, y, accept_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, multi_output, ensure_min_samples, ensure_min_features, y_numeric, warn_on_dtype, estimator)
#     529         y = y.astype(np.float64)
#     530
# --> 531     check_consistent_length(X, y)
#     532
#     533     return X, y
#
# /usr/local/lib/python3.5/dist-packages/sklearn/utils/validation.py in check_consistent_length(*arrays)
#     179     if len(uniques) > 1:
#     180         raise ValueError("Found input variables with inconsistent numbers of"
# --> 181                          " samples: %r" % [int(l) for l in lengths])
#     182
#     183
#
# ValueError: Found input variables with inconsistent numbers of samples: [1, 21613]
